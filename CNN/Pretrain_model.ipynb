# %% [markdown]
# VGG16
#
# VGG19
#
# Resnet
#
# Inception (Google Net)
#
# MobileNet
#
# NasNet
#
# Efficient Net

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
model = VGG16(weights='imagenet')
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
img_path = '/content/image/puppies.jpeg'

# %%
img = image.load_img(img_path,target_size=(224,224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img = np.expand_dims(img,axis=0)

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
prediction = model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
decode_predictions(prediction)
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# [[('n02101556', 'clumber', 0.7675447),
#   ('n02111500', 'Great_Pyrenees', 0.20000614),
#   ('n02104029', 'kuvasz', 0.015385268),
#   ('n02102480', 'Sussex_spaniel', 0.007341844),
#   ('n02108551', 'Tibetan_mastiff', 0.0040040403)]]

# %% [markdown]
# This will define us all the possibilities , breed of dog and all

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
model2 = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
img2_path = '/content/image/MAC.jpeg'

# %%
img2 = image.load_img(img2_path,target_size=(224,224)) # Load image with target size (224, 224)
img2 = image.img_to_array(img2) # Convert to NumPy array
img2 = np.expand_dims(img2,axis=0) #img2 = np.expand_dims(img,axis=0)
img2.shape # Verify shape
# Out:
# (1, 224, 224, 3)

# %%
prediction2 = model2.predict(img2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
decode_predictions(prediction2)
# Out:
# [[('n02971356', 'carton', 0.19530778),
#   ('n03291819', 'envelope', 0.15317461),
#   ('n03832673', 'notebook', 0.079912886),
#   ('n04548362', 'wallet', 0.07245565),
#   ('n03642806', 'laptop', 0.04632017)]]

# %%
img3_path = '/content/image/T_S.jpeg'

# %%
img3 = image.load_img(img3_path,target_size=(224,224)) # Load image with target size (224, 224)
img3 = image.img_to_array(img3) # Convert to NumPy array
img3 = np.expand_dims(img3,axis=0) #img2 = np.expand_dims(img,axis=0)
img3.shape # Verify shape
# Out:
# (1, 224, 224, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img3[0])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
prediction3 = model2.predict(img3)   #using resnet
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
prediction4 = model.predict(img3)    #using vgg
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
decode_predictions(prediction3)
# Out:
# [[('n04584207', 'wig', 0.67166907),
#   ('n02895154', 'breastplate', 0.10329703),
#   ('n03595614', 'jersey', 0.063326456),
#   ('n03980874', 'poncho', 0.030423917),
#   ('n02963159', 'cardigan', 0.020357003)]]

# %%
decode_predictions(prediction4)
# Out:
# [[('n04584207', 'wig', 0.97947973),
#   ('n04599235', 'wool', 0.0076706083),
#   ('n02963159', 'cardigan', 0.005331965),
#   ('n04325704', 'stole', 0.0025488099),
#   ('n03980874', 'poncho', 0.0017169487)]]
